# %% [markdown]
# <a href="https://colab.research.google.com/github/Charang203/Indoskill/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/symptom_Description(1).csv")
data.head(25)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
import numpy as cn

# %%
import numpy as cn
data=pd.read_csv("/symptom_Description(1).csv")
data.head(31)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
import pandas as pd
data=pd.read_csv("/dataset(1).csv")
data.head(30)
# Out:
#              Disease             Symptom_1              Symptom_2  \
# 0   Fungal infection               itching              skin_rash
# 1   Fungal infection             skin_rash   nodal_skin_eruptions
# 2   Fungal infection               itching   nodal_skin_eruptions
# 3   Fungal infection               itching              skin_rash
# 4   Fungal infection               itching              skin_rash
# 5   Fungal infection             skin_rash   nodal_skin_eruptions
# 6   Fungal infection               itching   nodal_skin_eruptions
# 7   Fungal infection               itching              skin_rash
# 8   Fungal infection               itching              skin_rash
# 9   Fungal infection               itching              skin_rash
# 10           Allergy   continuous_sneezing              shivering
# 11           Allergy             shivering                 chills
# 12           Allergy   continuous_sneezing                 chills
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("/dataset(1).csv")
sns.displot(data["Symptom_4"])

# %%
import pandas as pd
data=pd.read_csv("/symptom_precaution(1).csv")
data.head(40)
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
ndarray=[[1,20],["Disease ","Precaution "]]
data.head(25)
# Out:
#              Disease             Symptom_1              Symptom_2  \
# 0   Fungal infection               itching              skin_rash
# 1   Fungal infection             skin_rash   nodal_skin_eruptions
# 2   Fungal infection               itching   nodal_skin_eruptions
# 3   Fungal infection               itching              skin_rash
# 4   Fungal infection               itching              skin_rash
# 5   Fungal infection             skin_rash   nodal_skin_eruptions
# 6   Fungal infection               itching   nodal_skin_eruptions
# 7   Fungal infection               itching              skin_rash
# 8   Fungal infection               itching              skin_rash
# 9   Fungal infection               itching              skin_rash
# 10           Allergy   continuous_sneezing              shivering
# 11           Allergy             shivering                 chills
# 12           Allergy   continuous_sneezing                 chills
# ...

# %%
import pandas as pd
data=pd.read_csv("/Symptom-severity(1).csv")
data.head(20)
# Out:
#                  Symptom  weight
# 0                itching       1
# 1              skin_rash       3
# 2   nodal_skin_eruptions       4
# 3    continuous_sneezing       4
# 4              shivering       5
# 5                 chills       3
# 6             joint_pain       3
# 7           stomach_pain       5
# 8                acidity       3
# 9       ulcers_on_tongue       4
# 10        muscle_wasting       3
# 11              vomiting       5
# 12   burning_micturition       6
# 13    spotting_urination       6
# 14               fatigue       4
# 15           weight_gain       3
# 16               anxiety       4
# 17  cold_hands_and_feets       5
# 18           mood_swings       3
# 19           weight_loss       3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("/Symptom-severity(1).csv")
sns.displot(data["weight"])

# %%
plt.figure(figsize=(3,4))
sns.histplot(data=df, x='weight', kde=True)
plt.title('weight')
plt.xlabel('weight ')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f30ae2af16a6> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(3,4))
#       2 sns.histplot(data=df, x='weight', kde=True)
#       3 plt.title('weight')
#       4 plt.xlabel('weight ')
#       5 plt.ylabel('Count')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symptom  133 non-null    object
#  1   weight   133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
import matplotlib.pyplot as plt
Disease=[1,2,3]
Precaution_4=[2,5,3]
plt.plot(Disease,Precaution_4)
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("/symptom_precaution(1).csv")
sns.displot(data["Precaution_3"])

# %%
import matplotlib.pyplot as plt
data = [0,1,2,3]
ax=plt.subplots()
ax.barplot(data)
ax.set_xticklabels(['Data'])
ax.set_ylabel('Values')
ax.set_title('Box Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-05772e1ef5df> in <cell line: 4>()
#       2 data = [0,1,2,3]
#       3 ax=plt.subplots()
# ----> 4 ax.barplot(data)
#       5 ax.set_xticklabels(['Data'])
#       6 ax.set_ylabel('Values')
#
# AttributeError: 'tuple' object has no attribute 'barplot'

# %%
sns.scatterplot(data=data,
            x="Disease",
            y="Precaution_4")
# Out:
# <Axes: xlabel='Disease', ylabel='Precaution_4'>

# %%
data.corr()
# Out:
# <ipython-input-43-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.shape
# Out:
# (41, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disease       41 non-null     object
#  1   Precaution_1  41 non-null     object
#  2   Precaution_2  41 non-null     object
#  3   Precaution_3  40 non-null     object
#  4   Precaution_4  40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %%
data.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
data.tail()
# Out:
#             Disease                      Precaution_1  \
# 36     Heart attack                    call ambulance
# 37        Pneumonia                    consult doctor
# 38        Arthritis                          exercise
# 39  Gastroenteritis  stop eating solid food for while
# 40     Tuberculosis                       cover mouth
#
#                       Precaution_2     Precaution_3           Precaution_4
# 36          chew or swallow asprin        keep calm                    NaN
# 37                      medication             rest              follow up
# 38        use hot and cold therapy  try acupuncture                massage
# 39  try taking small sips of water             rest  ease back into eating
# 40                  consult doctor       medication                   rest

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = ['skin_rash','Heart attack']
sns.countplot(data)
plt.xlabel('Disease')
plt.ylabel('Count')
plt.title('Disease Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-696663d022e6> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 data = ['skin_rash','Heart attack']
# ----> 4 sns.countplot(data)
#       5 plt.xlabel('Disease')
#       6 plt.ylabel('Count')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# ...
